# %% [markdown]
# # Plot insect sounds

# %%
import librosa
import numpy as np
from numpy.typing import NDArray
import logging
import os
import sys
import IPython
import cv2
from matplotlib import pyplot as plt
sys.path.insert(0, os.path.abspath('..'))
from dataprocess.cwt.scalogram import plot_data
from dataprocess.cwt.cwt2 import rd_file

l_fmt = '[%(name)s %(levelname)s] %(asctime)s - %(message)s'
logging.basicConfig(level=logging.ERROR, format=l_fmt)
logger = logging.getLogger('dataprocess')

# %%
# logger.setLevel(logging.DEBUG)
logger.setLevel(logging.ERROR)

SOUND_FOLDER = '../data/sound/dronetest/'

# %% [markdown]
# ## Grasshopper 4 mono

# %%
im = cv2.imread(f'../data/sound/grasshopper-sound-4/gh-4.png')
plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))

# %%
SR_48K = 48000
d1, sr1, _ = rd_file(f'{SOUND_FOLDER}gh4_outdoor_uni.wav', sr=SR_48K)
IPython.display.Audio(data=d1, rate=sr1)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fig1 = plot_data(d1, sr1, type='all')

# %% [markdown]
# ## Grasshopper 4 denoised

# %%
d2, sr2, _ = rd_file(f'{SOUND_FOLDER}gh4_outdoor_uni_denoised.wav', sr=SR_48K)
IPython.display.Audio(data=d2, rate=sr2)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fig2 = plot_data(d2, sr2, type='all')

# %% [markdown]
# ## Grasshopper 4 filtered

# %%
d3, sr3, _ = rd_file(f'{SOUND_FOLDER}gh4_outdoor_uni_filter.wav', sr=SR_48K)
IPython.display.Audio(data=d3, rate=sr3)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fig3 = plot_data(d3, sr3, type='all')

# %% [markdown]
# ## Grasshopper 4 denoised & filtered

# %%
# order of denoising and filtering doesn't affect graph, difference of results is 0.
d4, sr4, _ = rd_file(f'{SOUND_FOLDER}gh4_outdoor_uni_denoised_filter.wav', sr=SR_48K)
IPython.display.Audio(data=d4, rate=sr4)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fig4 = plot_data(d4, sr4, type='all')

# %% [markdown]
# ## Grasshopper 4 Filtered and Denoised

# %%
d5, sr5, _ = rd_file(f'{SOUND_FOLDER}gh4_outdoor_uni_filter_denoised.wav', sr=SR_48K)
IPython.display.Audio(data=d5, rate=sr5)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fig5 = plot_data(d5, sr5, type='all')

# %% [markdown]
# ## Grasshopper 4 Filtered, Double Denoised

# %%
d6, sr6, _ = rd_file(f'{SOUND_FOLDER}gh4_outdoor_uni_denoised_filter_denoised.wav', sr=SR_48K)
IPython.display.Audio(data=d6, rate=sr6)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fig6 = plot_data(d6, sr6, type='all')

# %% [markdown]
# triple denoised

# %%
d7, sr7, _ = rd_file(f'{SOUND_FOLDER}gh4_outdoor_uni_denoised_filter_denoised_denoised.wav', sr=SR_48K)
IPython.display.Audio(data=d6, rate=sr6)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fig6 = plot_data(d6, sr6, type='all')
