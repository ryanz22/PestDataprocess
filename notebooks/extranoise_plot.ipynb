# %% [markdown]
# # Plot insect sounds

# %%
import librosa
import numpy as np
from numpy.typing import NDArray
import logging
import os
import sys
import IPython
import cv2
from matplotlib import pyplot as plt
sys.path.insert(0, os.path.abspath('..'))
from dataprocess.cwt.scalogram import plot_data
from dataprocess.cwt.cwt2 import rd_file

l_fmt = '[%(name)s %(levelname)s] %(asctime)s - %(message)s'
logging.basicConfig(level=logging.ERROR, format=l_fmt)
logger = logging.getLogger('dataprocess')

# %%
# logger.setLevel(logging.DEBUG)
logger.setLevel(logging.ERROR)

SOUND_FOLDER = '../data/sound/dronetest/'

# %% [markdown]
# ## Grasshopper 4 mono

# %%
im = cv2.imread(f'{SOUND_FOLDER}gh-4.png')
plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))

# %%
SR_48K = 48000
d1, sr1 = librosa.load(f'{SOUND_FOLDER}gh4_outdoor_uni.wav', sr=SR_48K)
IPython.display.Audio(data=d1, rate=sr1)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fig1 = plot_data(d1, sr1, type='all')

# %% [markdown]
# ## Grasshopper 4 denoised

# %%
d2, sr2 = librosa.load(f'{SOUND_FOLDER}gh4_outdoor_uni_denoised.wav', sr=SR_48K)
IPython.display.Audio(data=d2, rate=sr2)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fig2 = plot_data(d2, sr2, type='all')

# %% [markdown]
# ## Grasshopper 4 filtered

# %%
d3, sr3 = librosa.load(f'{SOUND_FOLDER}gh4_outdoor_uni_filter.wav', sr=SR_48K)
IPython.display.Audio(data=d3, rate=sr3)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fig3 = plot_data(d3, sr3, type='all')

# %% [markdown]
# ## Grasshopper 4 denoised & filtered

# %%
# order of denoising and filtering doesn't affect graph, difference of results is 0.
d4, sr4 = librosa.load(f'{SOUND_FOLDER}gh4_outdoor_uni_denoised_filter.wav', sr=SR_48K)
IPython.display.Audio(data=d4, rate=sr4)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fig4 = plot_data(d4, sr4, type='all')

# %% [markdown]
# ## Grasshopper 4 Filtered and Denoised

# %%
d5, sr5 = librosa.load(f'{SOUND_FOLDER}gh4_outdoor_uni_filter_denoised.wav', sr=SR_48K)
IPython.display.Audio(data=d5, rate=sr5)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fig5 = plot_data(d5, sr5, type='all')

# %%
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In [23], line 1
# ----> 1 fig6 = plot_data(d5-d4, sr5-sr4, type="all")
#
# File ~/projects/PestDataprocess/dataprocess/cwt/scalogram.py:44, in plot_data(d, sr, type, threshold)
#      42 if type == 'spectrogram' or type == 'all':
#      43     F_MAX = sr // 2
# ---> 44     S = librosa.feature.melspectrogram(y=d, sr=sr, n_mels=256, fmax=F_MAX)
#      45     S_db = librosa.power_to_db(S, ref=np.max)
#      47 if type == 'scalogram' or type == 'all':
#
# File ~/Library/Caches/pypoetry/virtualenvs/pestdataprocess-3DjAM6ra-py3.10/lib/python3.10/site-packages/librosa/util/decorators.py:88, in deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      86 extra_args = len(args) - len(all_args)
#      87 if extra_args <= 0:
# ---> 88     return f(*args, **kwargs)
#      90 # extra_args > 0
#      91 args_msg = [
#      92     "{}={}".format(name, arg)
#      93     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#      94 ]
#
# File ~/Library/Caches/pypoetry/virtualenvs/pestdataprocess-3DjAM6ra-py3.10/lib/python3.10/site-packages/librosa/feature/spectral.py:2056, in melspectrogram(y, sr, S, n_fft, hop_length, win_length, window, center, pad_mode, power, **kwargs)
#    2043 S, n_fft = _spectrogram(
#    2044     y=y,
#    2045     S=S,
#    (...)
#    2052     pad_mode=pad_mode,
#    2053 )
#    2055 # Build a Mel filter
# -> 2056 mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)
#    2058 return np.einsum("...ft,mf->...mt", S, mel_basis, optimize=True)
#
# File ~/Library/Caches/pypoetry/virtualenvs/pestdataprocess-3DjAM6ra-py3.10/lib/python3.10/site-packages/librosa/util/decorators.py:88, in deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      86 extra_args = len(args) - len(all_args)
#      87 if extra_args <= 0:
# ---> 88     return f(*args, **kwargs)
#      90 # extra_args > 0
#      91 args_msg = [
#      92     "{}={}".format(name, arg)
#      93     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#      94 ]
#
# File ~/Library/Caches/pypoetry/virtualenvs/pestdataprocess-3DjAM6ra-py3.10/lib/python3.10/site-packages/librosa/filters.py:224, in mel(sr, n_fft, n_mels, fmin, fmax, htk, norm, dtype)
#     221 weights = np.zeros((n_mels, int(1 + n_fft // 2)), dtype=dtype)
#     223 # Center freqs of each FFT bin
# --> 224 fftfreqs = fft_frequencies(sr=sr, n_fft=n_fft)
#     226 # 'Center freqs' of mel bands - uniformly spaced between limits
#     227 mel_f = mel_frequencies(n_mels + 2, fmin=fmin, fmax=fmax, htk=htk)
#
# File ~/Library/Caches/pypoetry/virtualenvs/pestdataprocess-3DjAM6ra-py3.10/lib/python3.10/site-packages/librosa/util/decorators.py:88, in deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      86 extra_args = len(args) - len(all_args)
#      87 if extra_args <= 0:
# ---> 88     return f(*args, **kwargs)
#      90 # extra_args > 0
#      91 args_msg = [
#      92     "{}={}".format(name, arg)
#      93     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#      94 ]
#
# File ~/Library/Caches/pypoetry/virtualenvs/pestdataprocess-3DjAM6ra-py3.10/lib/python3.10/site-packages/librosa/core/convert.py:1094, in fft_frequencies(sr, n_fft)
#    1070 @deprecate_positional_args
#    1071 def fft_frequencies(*, sr=22050, n_fft=2048):
#    1072     """Alternative implementation of `np.fft.fftfreq`
#    1073
#    1074     Parameters
#    (...)
#    1091
#    1092     """
# -> 1094     return np.fft.rfftfreq(n=n_fft, d=1.0 / sr)
#
# ZeroDivisionError: float division by zero

# %% [markdown]
# ## Grasshopper 4 Denoised, Filtered, and Denoised

# %%
d6, sr6 = librosa.load(f'{SOUND_FOLDER}gh4_outdoor_uni_denoised_filter_denoised.wav', sr=SR_48K)
IPython.display.Audio(data=d6, rate=sr6)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fig6 = plot_data(d6, sr6, type='all')
