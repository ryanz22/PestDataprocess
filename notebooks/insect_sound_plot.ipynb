# %% [markdown]
# # Plot insect sounds

# %%
import librosa
import numpy as np
from numpy.typing import NDArray
import logging
import os
import sys
import IPython
import cv2
from matplotlib import pyplot as plt
sys.path.insert(0, os.path.abspath('..'))

# Local imports from current directory - auto reload.
# Any changes you make to train.py will appear automatically.
# %load_ext autoreload
# %autoreload 2

from dataprocess.cwt.scalogram import plot_all
from dataprocess.cwt.cwt2 import rd_file

l_fmt = '[%(name)s %(levelname)s] %(asctime)s - %(message)s'
logging.basicConfig(level=logging.ERROR, format=l_fmt)
logger = logging.getLogger('dataprocess')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# logger.setLevel(logging.DEBUG)
logger.setLevel(logging.ERROR)

SOUND_FOLDER = '../data/sound/grasshopper-sound-4/'

# %% [markdown]
# ## Grasshopper 4 mono

# %%
im = cv2.imread(f'{SOUND_FOLDER}gh-4.png')
#IPython.display.display_jpeg(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))

# %%
d1, sr1, _ = rd_file(f'{SOUND_FOLDER}gh-4_mono_22050.wav')
IPython.display.Audio(data=d1, rate=sr1)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
FN_PREFIX = '../tmp/insect_sound_plot_'
tmp_fn = f'{FN_PREFIX}_all.png'
plot_all(d1, sr=sr1, out_fn=tmp_fn, threshold=-60, show_scale=True)

im = cv2.imread(tmp_fn)
#plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
IPython.display.display_png(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
# Out:
# plot graph as 10inch x 10inch
# N: 228217

# %% [markdown]
# ## Grasshopper 4 denoised

# %%
d2, sr2, _ = rd_file(f'{SOUND_FOLDER}gh-4_mono_22050_denoised.wav')
IPython.display.Audio(data=d2, rate=sr2)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
tmp_fn2 = f'{FN_PREFIX}_all_2.png'
plot_all(d2, sr=sr2, out_fn=tmp_fn, threshold=-60, show_scale=True)

im = cv2.imread(tmp_fn2)
#plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
IPython.display.display_png(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
# Out:
# plot graph as 10inch x 10inch
# N: 228217
# [ WARN:0@428.322] global /io/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('../tmp/insect_sound_plot__all_2.png'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[16], line 6
#       4 im = cv2.imread(tmp_fn2)
#       5 #plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
# ----> 6 IPython.display.display_png(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
#
# error: OpenCV(4.6.0) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %% [markdown]
# ## Grasshopper 4 filtered

# %%
d3, sr3, _ = rd_file(f'{SOUND_FOLDER}gh-4_mono_22050_filter.wav')
IPython.display.Audio(data=d3, rate=sr3)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
tmp_fn3 = f'{FN_PREFIX}_all_3.png'
plot_all(d3, sr=sr3, out_fn=tmp_fn, threshold=-60, show_scale=True)

im = cv2.imread(tmp_fn3)
#plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
IPython.display.display_png(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
# Out:
# plot graph as 10inch x 10inch
# N: 228217
# [ WARN:0@536.256] global /io/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('../tmp/insect_sound_plot__all_2.png'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[18], line 6
#       4 im = cv2.imread(tmp_fn3)
#       5 #plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
# ----> 6 IPython.display.display_png(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
#
# error: OpenCV(4.6.0) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %% [markdown]
# ## Grasshopper 4 denoised & filtered

# %%
d4, sr4, _ = rd_file(f'{SOUND_FOLDER}gh-4_mono_22050_denoised_filter.wav')
IPython.display.Audio(data=d4, rate=sr4)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
tmp_fn4 = f'{FN_PREFIX}_all_4.png'
plot_all(d4, sr=sr4, out_fn=tmp_fn, threshold=-60, show_scale=True)

im = cv2.imread(tmp_fn4)
IPython.display.display_png(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
# Out:
# plot graph as 10inch x 10inch
# N: 228217
# [ WARN:0@626.041] global /io/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('../tmp/insect_sound_plot__all_4.png'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[20], line 5
#       2 plot_all(d4, sr=sr4, out_fn=tmp_fn, threshold=-60, show_scale=True)
#       4 im = cv2.imread(tmp_fn4)
# ----> 5 IPython.display.display_png(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
#
# error: OpenCV(4.6.0) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %% [markdown]
# ## 44100 sample rate plot

# %%
fn_44k = f'{SOUND_FOLDER}/gh-4_mono_44k_denoised.wav'
y_44k, sr_44k = librosa.load(fn_44k, sr=None)
dura_44k = librosa.get_duration(y=y_44k, sr=sr_44k)
print(f'data shape: {y_44k.shape}, data:\n{y_44k[:20]}')
print(f'sample rate: {sr_44k}')
print(f'duration: {dura_44k}')
# Out:
# data shape: (456433,), data:
# [ 1.2207031e-04  1.2207031e-04  1.2207031e-04  3.0517578e-05
#  -6.1035156e-05 -1.2207031e-04 -1.8310547e-04 -1.8310547e-04
#  -9.1552734e-05 -3.0517578e-05  9.1552734e-05  1.5258789e-04
#   1.5258789e-04  1.2207031e-04  3.0517578e-05 -9.1552734e-05
#  -1.5258789e-04 -2.1362305e-04 -1.8310547e-04 -9.1552734e-05]
# sample rate: 44100
# duration: 10.349954648526078

# %%
tmp_fn5 = f'{FN_PREFIX}_all_5.png'
plot_all(y_44k, sr=sr_44k, out_fn=tmp_fn, threshold=-60, show_scale=True)

im = cv2.imread(tmp_fn4)
IPython.display.display_png(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
# Out:
# plot graph as 10inch x 10inch
# N: 456433
# [ WARN:0@713.248] global /io/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('../tmp/insect_sound_plot__all_4.png'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[23], line 5
#       2 plot_all(y_44k, sr=sr_44k, out_fn=tmp_fn, threshold=-60, show_scale=True)
#       4 im = cv2.imread(tmp_fn4)
# ----> 5 IPython.display.display_png(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
#
# error: OpenCV(4.6.0) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %% [markdown]
# ## Plot the same insect sing at different volume

# %% [markdown]
# ### Original volume plot

# %%
# Original volume
fn8 = f'{SOUND_FOLDER}volume_test/gh-4_mono_44k_denoised_0.wav'
# d8, sr8, _ = rd_file(fn8, sr=44100)
d8, sr8 = librosa.load(fn8, sr=44100)
max8 = np.max(np.abs(d8))
min8 = np.min(np.abs(d8))
mean8 = d8.mean()
# data = preprocessing.minmax_scale(data - mean, feature_range=(-1, 1))
print(f'max value of d8: {max8}, min: {min8}, mean: {mean8}')
IPython.display.Audio(data=d8, rate=sr8)
# Out:
# max value of d8: 0.186004638671875, min: 0.0, mean: -4.992495632905047e-06
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
tmp_fn8 = f'{FN_PREFIX}_all_8.png'
plot_all(d8, sr=sr8, out_fn=tmp_fn, threshold=-60, show_scale=True)

im = cv2.imread(tmp_fn8)
IPython.display.display_png(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
# Out:
# plot graph as 10inch x 10inch
# N: 176400
# [ WARN:0@796.149] global /io/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('../tmp/insect_sound_plot__all_8.png'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[25], line 5
#       2 plot_all(d8, sr=sr8, out_fn=tmp_fn, threshold=-60, show_scale=True)
#       4 im = cv2.imread(tmp_fn8)
# ----> 5 IPython.display.display_png(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
#
# error: OpenCV(4.6.0) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %% [markdown]
# ### 2 times louder plot

# %%
fn9 = f'{SOUND_FOLDER}volume_test/gh-4_mono_44k_denoised_0_volx2.wav'
# d9, sr9, _ = rd_file(fn9, sr=44100)
d9, sr9 = librosa.load(fn9, sr=44100)
max9 = np.max(np.abs(d9))
min9 = np.min(np.abs(d9))
mean9 = d9.mean()
# data = preprocessing.minmax_scale(data - mean, feature_range=(-1, 1))
print(f'max value of d9: {max9}, min: {min9}, mean: {mean9}')
IPython.display.Audio(data=d9, rate=sr9)
# Out:
# max value of d9: 0.37200927734375, min: 0.0, mean: -9.984991265810095e-06
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
tmp_fn9 = f'{FN_PREFIX}_all_9.png'
plot_all(d9, sr=sr9, out_fn=tmp_fn, threshold=-60, show_scale=True)

im = cv2.imread(tmp_fn9)
IPython.display.display_png(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
# Out:
# plot graph as 10inch x 10inch
# N: 176400
# [ WARN:0@907.804] global /io/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('../tmp/insect_sound_plot__all_9.png'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[27], line 5
#       2 plot_all(d9, sr=sr9, out_fn=tmp_fn, threshold=-60, show_scale=True)
#       4 im = cv2.imread(tmp_fn9)
# ----> 5 IPython.display.display_png(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
#
# error: OpenCV(4.6.0) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %% [markdown]
# ### 2 times weaker

# %%
fn10 = f'{SOUND_FOLDER}volume_test/gh-4_mono_44k_denoised_0_volx0_5.wav'
# d10, sr10, _ = rd_file(fn10, sr=44100)
d10, sr10 = librosa.load(fn10, sr=44100)
max10 = np.max(np.abs(d10))
min10 = np.min(np.abs(d10))
mean10 = d10.mean()
# data = preprocessing.minmax_scale(data - mean, feature_range=(-1, 1))
print(f'max value of d10: {max10}, min: {min10}, mean: {mean10}')
IPython.display.Audio(data=d10, rate=sr10)
# Out:
# max value of d10: 0.093017578125, min: 0.0, mean: -2.3313768906518817e-06
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
tmp_fn10 = f'{FN_PREFIX}_all_10.png'
plot_all(d10, sr=sr10, out_fn=tmp_fn, threshold=-60, show_scale=True)

im = cv2.imread(tmp_fn9)
IPython.display.display_png(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
# Out:
# plot graph as 10inch x 10inch
# N: 176400
# [ WARN:0@962.914] global /io/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('../tmp/insect_sound_plot__all_9.png'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[29], line 5
#       2 plot_all(d10, sr=sr10, out_fn=tmp_fn, threshold=-60, show_scale=True)
#       4 im = cv2.imread(tmp_fn9)
# ----> 5 IPython.display.display_png(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
#
# error: OpenCV(4.6.0) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
