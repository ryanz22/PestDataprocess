# %% [markdown]
# # Plot insect sounds

# %%
import librosa
import numpy as np
from numpy.typing import NDArray
import logging
import os
import sys
import IPython
import cv2
from matplotlib import pyplot as plt
sys.path.insert(0, os.path.abspath('..'))
from dataprocess.cwt.scalogram import plot_data
from dataprocess.cwt.cwt2 import rd_file

l_fmt = '[%(name)s %(levelname)s] %(asctime)s - %(message)s'
logging.basicConfig(level=logging.ERROR, format=l_fmt)
logger = logging.getLogger('dataprocess')

# %%
# logger.setLevel(logging.DEBUG)
logger.setLevel(logging.ERROR)

SOUND_FOLDER = '../data/sound/grasshopper-sound-4/'

# %% [markdown]
# ## Grasshopper 4 mono

# %%
im = cv2.imread(f'{SOUND_FOLDER}gh-4.png')
plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))

# %%
d1, sr1 = librosa.load(f'{SOUND_FOLDER}gh-4_mono_22050.wav')
IPython.display.Audio(data=d1, rate=sr1)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fig1 = plot_data(d1, sr1, type='all')

# %% [markdown]
# ## Grasshopper 4 denoised

# %%
d2, sr2 = librosa.load(f'{SOUND_FOLDER}gh-4_mono_22050_denoised.wav')
IPython.display.Audio(data=d2, rate=sr2)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fig2 = plot_data(d2, sr2, type='all')

# %% [markdown]
# ## Grasshopper 4 filtered

# %%
d3, sr3 = librosa.load(f'{SOUND_FOLDER}gh-4_mono_22050_filter.wav')
IPython.display.Audio(data=d3, rate=sr3)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fig3 = plot_data(d3, sr3, type='all')

# %% [markdown]
# ## Grasshopper 4 denoised & filtered

# %%
d4, sr4 = librosa.load(f'{SOUND_FOLDER}gh-4_mono_22050_denoised_filter.wav')
IPython.display.Audio(data=d4, rate=sr4)
# Out:
# /home/zhangjw/.cache/pypoetry/virtualenvs/pestdataprocess-pxU8UH9y-py3.10/lib/python3.10/site-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/.cache/pypoetry/virtualenvs/pestdataprocess-pxU8UH9y-py3.10/lib/python3.10/site-packages/librosa/core/audio.py:164, in load(path, sr, mono, offset, duration, dtype, res_type)
#     163 try:
# --> 164     y, sr_native = __soundfile_load(path, offset, duration, dtype)
#     166 except RuntimeError as exc:
#     167     # If soundfile failed, try audioread instead
#
# File ~/.cache/pypoetry/virtualenvs/pestdataprocess-pxU8UH9y-py3.10/lib/python3.10/site-packages/librosa/core/audio.py:195, in __soundfile_load(path, offset, duration, dtype)
#     193 else:
# ...

# %%
fig4 = plot_data(d4, sr4, type='all')
